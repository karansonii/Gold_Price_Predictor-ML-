# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import seaborn as sns

# %%
gold_data = pd.read_csv('/Users/karansoniii/Documents/Projects(ML)/Gold_Price_Prediction/gld_price_data.csv')

# %%
gold_data.head(5)
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
gold_data.shape
# Out:
# (2290, 6)

# %%
gold_data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
gold_data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
correlation = gold_data.corr(numeric_only=True)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size': 8}, cmap='Blues')
# Out:
# <Axes: >

# %%
print(correlation['GLD'].sort_values(ascending=True))
# Out:
# USO       -0.186360
# EUR/USD   -0.024375
# SPX        0.049345
# SLV        0.866632
# GLD        1.000000
# Name: GLD, dtype: float64

# %%
sns.histplot(gold_data['GLD'], color='blue')
# Out:
# <Axes: xlabel='GLD', ylabel='Count'>

# %%
X = gold_data.drop(['GLD','Date'], axis=1)
Y = gold_data['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
Test_data = regressor.predict(X_test)
Test_data
# Out:
# array([168.65979964,  81.79390003, 116.12930018, 127.62120067,
#        120.73190106, 154.75359829, 150.48199837, 126.02730017,
#        117.35779879, 125.89860085, 116.61440141, 171.85950102,
#        141.23459932, 167.58909818, 115.2705003 , 117.53450054,
#        138.10780289, 169.61340066, 159.56770301, 161.97849949,
#        155.14900034, 125.14109996, 176.06299999, 157.52340409,
#        125.25420032,  93.66869964,  77.71769987, 120.24520028,
#        119.00999917, 167.53349959,  87.99520044, 125.41790036,
#         91.23700065, 117.55910017, 121.13379951, 137.05130176,
#        115.59720091, 115.44990066, 147.40200015, 107.19810114,
#        104.7309023 ,  87.34399804, 126.43140047, 118.02369982,
#        151.00499897, 119.75910011, 108.2468002 , 107.95239792,
#         93.17360047, 127.10919769,  75.00790066, 113.68659942,
#        121.13409999, 111.38469907, 118.79739896, 121.14269917,
#        159.88160028, 166.84870131, 147.04069669,  86.23779915,
# ...

# %%
Score = metrics.r2_score(Y_test, Test_data)
print('R Sqaured Error:', Score)
# Out:
# R Sqaured Error: 0.9893133500484496

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='blue', label='Actual Value')
plt.plot(Test_data, color='green', label='Predicted Value')
plt.title('Actual Values Vs Predicted Values')
plt.xlabel('NUMBER OF VALUES')
plt.ylabel('GLD PRICE')
plt.legend()
plt.show()

# %%
import pickle
pickle.dump(gold_data, open('gold_data.pkl', 'wb'))
pickle.dump(Score, open('gold_data.pkl', 'wb'))
